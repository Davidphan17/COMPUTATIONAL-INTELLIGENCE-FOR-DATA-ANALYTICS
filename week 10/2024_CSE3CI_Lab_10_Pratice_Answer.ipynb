# %% [markdown]
# # Time-Series Forecasting: Predicting Stock Prices Using An LSTM Model

# %% [markdown]
# In this practice, we are going to use the stock price history data of TESLA, which is available free from Yahoo Finance here: https://finance.yahoo.com/quote/TSLA/history?period1=1436486400&period2=1594339200&interval=1d&filter=history&frequency=1d

# %% [markdown]
# ### Load Data
# print out the first 5 rows

# %%
import pandas as pd

df=pd.read_csv("TSLA.csv")
print('Number of rows and columns:', df.shape)
df.head()
# Out:
# Number of rows and columns: (1259, 7)
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 1  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 2  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 3  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000
# 4  2015-07-16  52.844002  53.439999  52.632000  53.335999  53.335999   8080000

# %% [markdown]
# ### Plot the "Close" stock price based on Date

# %%
import matplotlib.pyplot as plt

## plot graph
plot_df = df[["Date", "Close"]]
plot_df['Date'] = pd.to_datetime(plot_df['Date'], infer_datetime_format=True) #convert from string to datetime
#Set datatime as dataframe index
plot_df = plot_df.set_index(['Date'])

plt.figure(figsize=(15,10))
plt.plot(plot_df)
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\py37tf\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ### Extract the column values that you are going to use from pandas dataframe
# Here we are going to use the "Close" stock price to do the forecasting

# %%
stock = df.iloc[:, 4:5]
# or you can use this following:
# stock = df[["Close"]]

# %% [markdown]
# ### Get values from dataframe which returns as numpy array

# %%
dataset = stock.values

# %% [markdown]
# ### Normalize the data with Min-Max Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# normalizing the data
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# ### split the data into training and test
# using first 800 rows for training and the rest 459 for testing

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=459, shuffle=False)

# %% [markdown]
# ### Create the dataset that we are going to feed to LSTM
# Define the function to create the dataset, with time (lag) and dataset as the function parmenters/arguments.
#
# Then we apply this function on our training and testing dataset with a time-step of 60

# %%
import numpy as np

# convert the array of values into a matrix (the format requireb by LSTM)
def create_dataset(dataset, time=1):
    data_X, data_Y = [], []
    for i in range(len(dataset)-time-1):
        a = dataset[i:(i+time), 0]
        data_X.append(a)
        data_Y.append(dataset[i + time, 0])
    return np.array(data_X), np.array(data_Y)

time = 60
train_X, train_Y = create_dataset(train, time)
test_X, test_Y = create_dataset(test, time)

# %%
train_X.shape
# Out:
# (739, 60)

# %% [markdown]
# ### Reshape the data to the input format that required by LSTM
# Format that required by LSTM: (samples_size, time-step, features).

# %%
train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

# %% [markdown]
# ### Build a LSTM model
# Build a LSTM model with 4 LSTM layer, and each layer with a 50 units/nodes. After each LSTM layer, add a dropout layer with 20% dropout rate. At last, apply a dense layer. Remember to define input_shape in the first layer and set return_sequences = True for all LSTM layer except the layer LSTM layer.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (train_X.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37tf\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ### Compile and train the model
# use adam as optimizer and mean_squared_error as the loss function. use batch_size of 32 and epochs of 100 for training, set validation_data as the test dataset to monitor the training process

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(train_X, train_Y, validation_data=(test_X, test_Y), epochs = 100, batch_size = 32)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37tf\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 739 samples, validate on 398 samples
# Epoch 1/100
# 739/739 [==============================] - 4s 5ms/step - loss: 0.0025 - val_loss: 0.0215
# Epoch 2/100
# 739/739 [==============================] - 3s 4ms/step - loss: 5.9686e-04 - val_loss: 0.0137
# Epoch 3/100
# 739/739 [==============================] - 3s 4ms/step - loss: 5.1179e-04 - val_loss: 0.0061
# Epoch 4/100
# 739/739 [==============================] - 3s 4ms/step - loss: 4.7047e-04 - val_loss: 0.0066
# Epoch 5/100
# 739/739 [==============================] - 3s 4ms/step - loss: 4.3728e-04 - val_loss: 0.0097
# Epoch 6/100
# 739/739 [==============================] - 3s 4ms/step - loss: 4.2859e-04 - val_loss: 0.0071
# Epoch 7/100
# 739/739 [==============================] - 3s 4ms/step - loss: 4.0503e-04 - val_loss: 0.0093
# Epoch 8/100
# 739/739 [==============================] - 3s 4ms/step - loss: 3.8975e-04 - val_loss: 0.0062
# Epoch 9/100
# 739/739 [==============================] - 3s 4ms/step - loss: 3.7500e-04 - val_loss: 0.0059
# Epoch 10/100
# 739/739 [==============================] - 3s 4ms/step - loss: 3.5282e-04 - val_loss: 0.0054
# Epoch 11/100
# 739/739 [==============================] - 3s 4ms/step - loss: 4.2235e-04 - val_loss: 0.0075
# Epoch 12/100
# 739/739 [==============================] - 3s 4ms/step - loss: 3.4174e-04 - val_loss: 0.0066
# Epoch 13/100
# 739/739 [==============================] - 3s 4ms/step - loss: 3.1924e-04 - val_loss: 0.0064
# Epoch 14/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.7081e-04 - val_loss: 0.0044
# Epoch 15/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.8463e-04 - val_loss: 0.0052
# Epoch 16/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.9622e-04 - val_loss: 0.0054
# Epoch 17/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.7522e-04 - val_loss: 0.0053
# Epoch 18/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.6497e-04 - val_loss: 0.0058
# Epoch 19/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.5957e-04 - val_loss: 0.0045
# Epoch 20/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.9678e-04 - val_loss: 0.0056
# Epoch 21/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3314e-04 - val_loss: 0.0058
# Epoch 22/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.4310e-04 - val_loss: 0.0060
# Epoch 23/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3547e-04 - val_loss: 0.0072
# Epoch 24/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3480e-04 - val_loss: 0.0063
# Epoch 25/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3227e-04 - val_loss: 0.0050
# Epoch 26/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3630e-04 - val_loss: 0.0078
# Epoch 27/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3851e-04 - val_loss: 0.0049
# Epoch 28/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.1787e-04 - val_loss: 0.0071
# Epoch 29/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.3686e-04 - val_loss: 0.0051
# Epoch 30/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.0852e-04 - val_loss: 0.0049
# Epoch 31/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.1834e-04 - val_loss: 0.0065
# Epoch 32/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.2705e-04 - val_loss: 0.0085
# Epoch 33/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.9349e-04 - val_loss: 0.0056
# Epoch 34/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.9756e-04 - val_loss: 0.0066
# Epoch 35/100
# 739/739 [==============================] - 3s 4ms/step - loss: 2.1029e-04 - val_loss: 0.0074
# Epoch 36/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.9164e-04 - val_loss: 0.0071
# Epoch 37/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.8541e-04 - val_loss: 0.0059
# Epoch 38/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.7084e-04 - val_loss: 0.0071
# Epoch 39/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.7734e-04 - val_loss: 0.0056
# Epoch 40/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.7872e-04 - val_loss: 0.0068
# Epoch 41/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.6726e-04 - val_loss: 0.0056
# Epoch 42/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.7789e-04 - val_loss: 0.0054
# Epoch 43/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.5728e-04 - val_loss: 0.0048
# Epoch 44/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.6251e-04 - val_loss: 0.0069
# Epoch 45/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.7177e-04 - val_loss: 0.0063
# Epoch 46/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.6550e-04 - val_loss: 0.0063
# Epoch 47/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.5780e-04 - val_loss: 0.0056
# Epoch 48/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.6268e-04 - val_loss: 0.0066
# Epoch 49/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.7441e-04 - val_loss: 0.0053
# Epoch 50/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.6682e-04 - val_loss: 0.0063
# Epoch 51/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.5701e-04 - val_loss: 0.0052
# Epoch 52/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.4353e-04 - val_loss: 0.0050
# Epoch 53/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3266e-04 - val_loss: 0.0045
# Epoch 54/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3905e-04 - val_loss: 0.0061
# Epoch 55/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3871e-04 - val_loss: 0.0049
# Epoch 56/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3098e-04 - val_loss: 0.0047
# Epoch 57/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3926e-04 - val_loss: 0.0052
# Epoch 58/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3029e-04 - val_loss: 0.0053
# Epoch 59/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.5715e-04 - val_loss: 0.0038
# Epoch 60/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3720e-04 - val_loss: 0.0050
# Epoch 61/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3958e-04 - val_loss: 0.0047
# Epoch 62/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.2043e-04 - val_loss: 0.0043
# Epoch 63/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.2983e-04 - val_loss: 0.0054
# Epoch 64/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.5573e-04 - val_loss: 0.0057
# Epoch 65/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3180e-04 - val_loss: 0.0049
# Epoch 66/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3161e-04 - val_loss: 0.0041
# Epoch 67/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1448e-04 - val_loss: 0.0045
# Epoch 68/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1683e-04 - val_loss: 0.0040
# Epoch 69/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.2166e-04 - val_loss: 0.0041
# Epoch 70/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.2399e-04 - val_loss: 0.0041
# Epoch 71/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1704e-04 - val_loss: 0.0036
# Epoch 72/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.7793e-05 - val_loss: 0.0042
# Epoch 73/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0860e-04 - val_loss: 0.0034
# Epoch 74/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0683e-04 - val_loss: 0.0040
# Epoch 75/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.3082e-04 - val_loss: 0.0040
# Epoch 76/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1771e-04 - val_loss: 0.0031
# Epoch 77/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0756e-04 - val_loss: 0.0032
# Epoch 78/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1571e-04 - val_loss: 0.0018
# Epoch 79/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.2103e-04 - val_loss: 0.0030
# Epoch 80/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0808e-04 - val_loss: 0.0029
# Epoch 81/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.5111e-05 - val_loss: 0.0033
# Epoch 82/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.8929e-05 - val_loss: 0.0019
# Epoch 83/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0937e-04 - val_loss: 0.0034
# Epoch 84/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.2145e-04 - val_loss: 0.0031
# Epoch 85/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0732e-04 - val_loss: 0.0020
# Epoch 86/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0132e-04 - val_loss: 0.0030
# Epoch 87/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0624e-04 - val_loss: 0.0032
# Epoch 88/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0284e-04 - val_loss: 0.0030
# Epoch 89/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1474e-04 - val_loss: 0.0018
# Epoch 90/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1819e-04 - val_loss: 0.0026
# Epoch 91/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1216e-04 - val_loss: 0.0028
# Epoch 92/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0835e-04 - val_loss: 0.0025
# Epoch 93/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.1743e-05 - val_loss: 0.0019
# Epoch 94/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0357e-04 - val_loss: 0.0037
# Epoch 95/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.0072e-04 - val_loss: 0.0023
# Epoch 96/100
# 739/739 [==============================] - 3s 4ms/step - loss: 1.1476e-04 - val_loss: 0.0033
# Epoch 97/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.9314e-05 - val_loss: 0.0029
# Epoch 98/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.6107e-05 - val_loss: 0.0020
# Epoch 99/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.8913e-05 - val_loss: 0.0019
# Epoch 100/100
# 739/739 [==============================] - 3s 4ms/step - loss: 9.8532e-05 - val_loss: 0.0023

# %% [markdown]
# ### Make Predictions
# apply model to both training set and testing set

# %%
train_predict = model.predict(train_X)
test_predict = model.predict(test_X)

# %% [markdown]
# ### Inverting predictions
# transform predictions back with the defined scaler

# %%
train_predict = scaler.inverse_transform(train_predict)
train_Y = scaler.inverse_transform([train_Y])
test_predict = scaler.inverse_transform(test_predict)
test_Y = scaler.inverse_transform([test_Y])

# %% [markdown]
# ### Evaluate model performance for both Training and Testing (based on RMSE and R squared)

# %%
import math
from sklearn.metrics import mean_squared_error, r2_score

# calculate root mean squared error
train_score = math.sqrt(mean_squared_error(train_Y[0], train_predict[:,0]))
print('Train_performance: %.2f RMSE' % (train_score))
test_performance = math.sqrt(mean_squared_error(test_Y[0], test_predict[:,0]))
print('Test_performance: %.2f RMSE' % (test_performance))

# calculate r_squared
train_r_squared = r2_score(train_Y[0], train_predict[:,0])
print('Train_performance: %.2f R2' % (train_r_squared))
test_r_squared = r2_score(test_Y[0], test_predict[:,0])
print('Test_performance: %.2f R2' % (test_r_squared))
# Out:
# Train_performance: 1.86 RMSE
# Test_performance: 11.97 RMSE
# Train_performance: 0.98 R2
# Test_performance: 0.94 R2

# %% [markdown]
# ### Plot the orginal Data and the Predictions

# %%
#plotting train and test predictions 
train_plot = np.empty_like(dataset)
train_plot[:, :] = np.nan
train_plot[time:len(train_predict)+time, :] = train_predict

test_plot = np.empty_like(dataset)
test_plot[:, :] = np.nan
test_plot[len(train_predict)+(time*2)+1:len(dataset)-1, :] = test_predict

plt.figure(figsize=(15,10))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(train_plot)
plt.plot(test_plot)
plt.show()
